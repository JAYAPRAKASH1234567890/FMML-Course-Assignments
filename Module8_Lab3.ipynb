# %% [markdown]
# <a href="https://colab.research.google.com/github/JAYAPRAKASH1234567890/FMML-Course-Assignments/blob/main/Module8_Lab3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# <table class="tfo-notebook-buttons" align="left">
#   <td>
#     <a target="_blank" href="https://colab.research.google.com/drive/1TuDbIyso6irdyBFgaHRpC-PxUICWPHcS?usp=sharing"><img height="32px" src="https://colab.research.google.com/img/colab_favicon.ico" />Run in Google Colab</a>
#   </td>
#   <td>
#     <a target="_blank" href="https://github.com/Foundations-in-Modern-Machine-Learning/course-contents/tree/main/Bayesian/"><img src="https://www.tensorflow.org/images/GitHub-Mark-32px.png" />View source on GitHub</a>
#   </td>
# </table>
# <br>
# <br>
# <br>

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2023-06-15 05:32:17--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   207MB/s    in 0.3s
#
# 2023-06-15 05:32:19 (207 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 37889   1102.4399v3  Multi-class classification methods based on bo...  stat
# 6253   1610.04929v1  We propose a novel probabilistic dimensionalit...  stat
# 33615   1410.0948v1  During the earliest phase of architectural des...    cs
# 7700   1802.09127v1  Recent advances in deep reinforcement learning...  stat
# 10921  1612.08392v1  Multivariate Pattern (MVP) classification hold...  stat
# ...             ...                                                ...   ...
# 29218  1708.07791v2  We propose several cost functions for registra...    cs
# 38321  1606.00414v1  In several domains such as linguistics, molecu...    cs
# 13021   1405.3726v1  Social network analysis (SNA), which is a rese...    cs
# 22474  1608.07597v3  Kernel-based K-means clustering has gained pop...  stat
# 40955   1310.3407v1  One major bottleneck in the practical implemen...    cs
#
#                                                    title  year  \
# 37889  Semi-supervised logistic discrimination for fu...  2011
# 6253   Probabilistic Dimensionality Reduction via Str...  2016
# 33615  Contributions of natural ventilation on therma...  2014
# 7700   Deep Bayesian Bandits Showdown: An Empirical C...  2018
# 10921  Multi-Region Neural Representation: A novel mo...  2016
# ...                                                  ...   ...
# 29218           Shape Registration with Directional Data  2017
# 38321  On a Possible Similarity between Gene and Sema...  2015
# 13021            Topic words analysis based on LDA model  2014
# 22474  A Randomized Approach to Efficient Kernel Clus...  2016
# 40955  Joint Indoor Localization and Radio Map Constr...  2013
#
#                                                 keywords
# 37889  [classification, unlabeled, functional, discus...
# 6253   [probabilistic, dimensionality, reduction, fra...
# 33615  [architectural, practitioners, analyzing, requ...
# 7700   [reinforcement, significant, performance, appl...
# 10921  [multivariate, classification, potential, empl...
# ...                                                  ...
# 29218  [functions, registration, euclidean, euclidean...
# 38321  [linguistics, molecular, understand, structure...
# 13021  [describing, connection, visualize, registered...
# 22474  [clustering, popularity, simplicity, represent...
# 40955  [bottleneck, practical, implementation, locali...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 37889    [classification, unlabeled, functional, discus...
# 6253     [probabilistic, dimensionality, reduction, fra...
# 33615    [architectural, practitioners, analyzing, requ...
# 7700     [reinforcement, significant, performance, appl...
# 10921    [multivariate, classification, potential, empl...
#                                ...
# 612      [developed, multimodal, translation, challenge...
# 10927    [convergence, hausdorff, estimating, dimension...
# 11042    [stochastic, continuum, functions, rightarrow,...
# 25856    [preprocessing, processing, biometric, recogni...
# 22463    [analyzing, statistical, algorithm, developed,...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8695 words.
# Out of those 4591 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="d4586b13-3490-4d93-873d-bd4235ac2626" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d4586b13-3490-4d93-873d-bd4235ac2626")) {                    Plotly.newPlot(                        "d4586b13-3490-4d93-873d-bd4235ac2626",                        [{"x":["parameter","procedure","simulations","selection","regularization","parameters","functional","information","supervised","classification","effectiveness","algorithm","introduce","unlabeled","theoretic","viewpoints","estimated","discussed","discrimination","correctly","facilitate","dimensional","interpreted","motivates","projection","discriminative","intrinsic","formulation","connected","performed","extensive","structure","demonstrate","clustering","scientific","structures","embedding","equivalently","interpretation","representations","discovery","framework","integrate","visualization","naturally","generative","representation","experiments","reduction","traditional","dimensionality","downstream","probabilistic","topographic","evolutionary","constraints","geometric","specifications","prototype","manageable","optimizes","different","contributions","architectural","contribute","developing","significantly","requirements","estimates","performance","decisions","technique","practitioners","analyzing","evaluates","according","communication","potential","generates","sequential","algorithms","improvement","simulation","preferences","solutions","presented","adequately","iterative","important","optimization","alternative","synthesize","challenge","practical","converging","approaches","highlight","significant","approximation","understand","established","exploration","benchmark","extension","developed","successful","comparison","posterior","reinforcement","exploitation","attractive","applications","approximate","uncertainty","empirical","particular","contextual","neuroscientists","snapshots","introduces","fluctuation","decreasing","activities","multivariate","consonants","opportunity","techniques","overcoming","anatomical","challenges","therefore","smoothing","categories","effective","automatically","employing","experimental","visualizing","principled","establish","variables","construct","hierarchical","informative","computational","contribution","unsupervised","usefulness","complexity","maximally","synthetic","capturing","functions","distributed","factorization","tractable","properties","empirically","separability","scalability","favorable","implementation","demonstrates","separable","perspective","assumption","reformulate","deblurring","available","prototypical","denoising","measurability","compression","necessary","learnability","measurable","subspaces","hypotheses","condition","additionally","universally","compactness","guaranteed","distances","preserving","utilising","transformations","correlated","transforms","correlations","previously","investigate","similarity","transformation","resulting","forecasting","inference","optimizing","evaluation","autonomous"],"y":[130,128,36,172,74,245,43,693,188,557,222,780,352,57,43,9,55,50,24,29,36,182,24,6,45,102,46,81,64,126,173,323,545,137,37,150,104,6,58,216,51,549,42,26,52,106,366,634,99,170,64,13,147,4,59,142,76,9,22,1,11,735,46,13,24,48,255,54,87,894,52,244,12,69,15,102,53,152,54,76,607,152,77,33,125,178,7,62,350,271,82,18,135,155,7,484,25,258,104,66,54,68,232,72,187,73,139,34,136,18,18,409,107,105,153,277,45,0,2,74,1,15,49,14,0,12,387,8,6,112,156,16,71,236,180,32,379,10,33,46,131,92,110,45,289,62,156,26,252,12,140,41,211,103,43,28,197,84,3,45,14,123,55,25,73,74,5,10,280,5,48,2,37,72,8,2,21,30,46,61,3,7,19,31,53,3,34,32,16,34,101,121,144,52,129,16,207,43,243,60],"type":"bar"},{"x":["parameter","procedure","simulations","selection","regularization","para ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4591,), (4591, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8191666666666667

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Hand</span> <span style=''>Tracking</span> <span style=''>based</span> <span style=''>on</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Hierarchical</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Clustering</span> <span style=''>of</span> <span style=''>Range</span> <span style=''>Data</span> <br/><br/><span style=''>Fast</span> <span style=''>and</span> <span style=''>robust</span> <span style=''>hand</span> <span style='background-color:rgba(0, 255, 0, 0.7310924369747899);'>segmentation</span> <span style=''>and</span> <span style=''>tracking</span> <span style=''>is</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.30666666666666664);'>essential</span> <span style=''>basis</span> <span style=''>for</span> <span style=''>gesture</span> <span style='background-color:rgba(0, 255, 0, 0.6285714285714287);'>recognition</span> <span style=''>and</span> <span style=''>thus</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>important</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>component</span> <span style=''>for</span> <span style=''>contact</span> <span style=''>less</span> <span style=''>human</span> <span style=''>computer</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>interaction</span> <span style=''>(HCI)</span> <span style=''>Hand</span> <span style=''>gesture</span> <span style='background-color:rgba(0, 255, 0, 0.6285714285714287);'>recognition</span> <span style=''>based</span> <span style=''>on</span> <span style=''>2D</span> <span style=''>video</span> <span style=''>data</span> <span style=''>has</span> <span style=''>been</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>intensively</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>investigated</span> <span style=''>However</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>practical</span> <span style='background-color:rgba(0, 255, 0, 0.30612244897959184);'>scenarios</span> <span style=''>purely</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>intensity</span> <span style=''>based</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approaches</span> <span style=''>suffer</span> <span style=''>from</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>uncontrollable</span> <span style='background-color:rgba(0, 255, 0, 0.52);'>environmental</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>conditions</span> <span style=''>like</span> <span style='background-color:rgba(0, 255, 0, 0.8461538461538461);'>cluttered</span> <span style='background-color:rgba(0, 255, 0, 0.5849056603773585);'>background</span> <span style=''>colors</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>present</span> <span style=''>a</span> <span style=''>real</span> <span style=''>time</span> <span style=''>hand</span> <span style='background-color:rgba(0, 255, 0, 0.7310924369747899);'>segmentation</span> <span style=''>and</span> <span style=''>tracking</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>using</span> <span style=''>Time</span> <span style=''>of</span> <span style=''>Flight</span> <span style=''>(ToF)</span> <span style=''>range</span> <span style=''>cameras</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>intensity</span> <span style=''>data</span> <span style=''>The</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>intensity</span> <span style=''>and</span> <span style=''>range</span> <span style='background-color:rgba(0, 255, 0, 0.3162393162393162);'>information</span> <span style=''>is</span> <span style=''>fused</span> <span style=''>into</span> <span style=''>one</span> <span style=''>pixel</span> <span style=''>value</span> <span style='background-color:rgba(0, 255, 0, 0.5652173913043478);'>repres ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Compressive</span> <span style=''>sensing</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>adaptation</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>polynomial</span> <span style=''>chaos</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>expansions</span> <br/><br/><span style=''>Basis</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>adaptation</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Homogeneous</span> <span style=''>Chaos</span> <span style=''>spaces</span> <span style=''>rely</span> <span style=''>on</span> <span style=''>a</span> <span style=''>suitable</span> <span style=''>rotation</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>underlying</span> <span style=''>Gaussian</span> <span style=''>germ</span> <span style=''>Several</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>rotations</span> <span style=''>have</span> <span style=''>been</span> <span style=''>proposed</span> <span style=''>in</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>literature</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>resulting</span> <span style=''>in</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>adaptations</span> <span style=''>with</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>different</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>convergence</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>properties</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>present</span> <span style=''>a</span> <span style=''>new</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>adaptation</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>mechanism</span> <span style=''>that</span> <span style=''>builds</span> <span style=''>on</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>compressive</span> <span style=''>sensing</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithms</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>resulting</span> <span style=''>in</span> <span style=''>a</span> <span style=''>reduced</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>polynomial</span> <span style=''>chaos</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approximation</span> <span style=''>with</span> <span style=''>optimal</span> <span style=''>sparsity</span> <span style=''>The</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>developed</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>adaptation</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>consists</span> <span style=''>of</span> <span style=''>a</span> <span style=''>two</span> <span style=''>step</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>optimization</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>procedure</span> <span style=''>that</span> <span style=''>computes</span> <span style=''>the</span> <span style=''>optimal</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>coefficients</span> <span style=''>and</span> <span style=''>the</span> <span style=''>input</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>projection</span> <span style=''>matrix</span> <span style=''>of</span> <span style=''>a</span> <span style=''>low</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensional</span> <span style=''>chaos</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>expansion</span> <span style=''>with</span> <span style=''>respect</span> <span style=''>to</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimally</span> <span style=''>rotated</span> <span style='' ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>PAC</span> <span style=''>Bayesian</span> <span style='background-color:rgba(255, 0, 0, 0.40740740740740744);'>Inequalities</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.5);'>Martingales</span> <br/><br/><span style=''>We</span> <span style=''>present</span> <span style=''>a</span> <span style=''>set</span> <span style=''>of</span> <span style=''>high</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>probability</span> <span style='background-color:rgba(255, 0, 0, 0.40740740740740744);'>inequalities</span> <span style=''>that</span> <span style=''>control</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.4358974358974359);'>concentration</span> <span style=''>of</span> <span style=''>weighted</span> <span style=''>averages</span> <span style=''>of</span> <span style=''>multiple</span> <span style=''>(possibly</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>uncountably</span> <span style=''>many)</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>simultaneously</span> <span style=''>evolving</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>interdependent</span> <span style='background-color:rgba(255, 0, 0, 0.5);'>martingales</span> <span style=''>Our</span> <span style=''>results</span> <span style=''>extend</span> <span style=''>the</span> <span style=''>PAC</span> <span style=''>Bayesian</span> <span style=''>analysis</span> <span style=''>in</span> <span style=''>learning</span> <span style=''>theory</span> <span style=''>from</span> <span style=''>the</span> <span style=''>iid</span> <span style=''>setting</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.5);'>martingales</span> <span style=''>opening</span> <span style=''>the</span> <span style=''>way</span> <span style=''>for</span> <span style=''>its</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>application</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>importance</span> <span style=''>weighted</span> <span style=''>sampling</span> <span style='background-color:rgba(0, 255, 0, 0.5454545454545455);'>reinforcement</span> <span style=''>learning</span> <span style=''>and</span> <span style=''>other</span> <span style='background-color:rgba(0, 255, 0, 0.7647058823529412);'>interactive</span> <span style=''>learning</span> <span style=''>domains</span> <span style=''>as</span> <span style=''>well</span> <span style=''>as</span> <span style=''>many</span> <span style=''>other</span> <span style=''>domains</span> <span style=''>in</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>probability</span> <span style=''>theory</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>statistics</span> <span style=''>where</span> <span style='background-color:rgba(255, 0, 0, 0.5);'>martingales</span> <span style=''>are</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>encountered</span> <span style=''>We</span> <span style=''>also</span> <span style=''>present</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>comparison</span> <span style='background-color:rgba(255, 0, 0, 0.33333333333333326);'>inequality</span> <span style=''>that</span> <span style=''>bounds</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>expectation</span> <span style=''>of</span> <span style=''>a</span> <span style=''>convex</span> <span style=''>function</span> <span style=''>of</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.33333333333333326);'>martingale</span> <span style='background-color:rgba(0, 255, 0, 0.3406593406593407);'>difference</span> <span style=''>sequence</span> <span style=''>shifted</span> <span style=''>to</span> <span style=''>the</span> <span style=''>01</span> <span style=''>interval</span> <span style=''>by</span> < ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Small</span> <span style=''>Moving</span> <span style=''>Window</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Calibration</span> <span style=''>Models</span> <span style=''>for</span> <span style=''>Soft</span> <span style=''>Sensing</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Processes</span> <span style=''>with</span> <span style=''>Limited</span> <span style=''>History</span> <br/><br/><span style=''>Five</span> <span style=''>simple</span> <span style=''>soft</span> <span style=''>sensor</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>methodologies</span> <span style=''>with</span> <span style=''>two</span> <span style=''>update</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>conditions</span> <span style=''>were</span> <span style=''>compared</span> <span style=''>on</span> <span style=''>two</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>experimentally</span> <span style=''>obtained</span> <span style=''>datasets</span> <span style=''>and</span> <span style=''>one</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>simulated</span> <span style=''>dataset</span> <span style=''>The</span> <span style=''>soft</span> <span style=''>sensors</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>investigated</span> <span style=''>were</span> <span style=''>moving</span> <span style=''>window</span> <span style=''>partial</span> <span style=''>least</span> <span style=''>squares</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regression</span> <span style=''>(and</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>recursive</span> <span style=''>variant)</span> <span style=''>moving</span> <span style=''>window</span> <span style=''>random</span> <span style=''>forest</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regression</span> <span style=''>the</span> <span style=''>mean</span> <span style=''>moving</span> <span style=''>window</span> <span style=''>of</span> <span style=''>y</span> <span style=''>and</span> <span style=''>a</span> <span style=''>novel</span> <span style=''>random</span> <span style=''>forest</span> <span style=''>partial</span> <span style=''>least</span> <span style=''>squares</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regression</span> <span style=''>ensemble</span> <span style=''>(RF</span> <span style=''>PLS)</span> <span style=''>all</span> <span style=''>of</span> <span style=''>which</span> <span style=''>can</span> <span style=''>be</span> <span style=''>used</span> <span style=''>with</span> <span style=''>small</span> <span style=''>sample</span> <span style=''>sizes</span> <span style=''>so</span> <span style=''>that</span> <span style=''>they</span> <span style=''>can</span> <span style=''>be</span> <span style=''>rapidly</span> <span style=''>placed</span> <span style=''>online</span> <span style=''>It</span> <span style=''>was</span> <span style=''>found</span> <span style=''>that</span> <span style=''>on</span> <span style=''>two</span> <span style=''>of</span> <span style=''>the</span> <span style=''>datasets</span> <span style=''>studied</span> <span style=''>small</span> <span style=''>window</span> <span style=''>sizes</span> <span style=''>led</span> <span style=''>to</span> <span style=''>the</span> <span style=''>lowest</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>prediction</span> <span style=''>errors</span> <span style=''>for</span> <span style=''>all</span> <span style=''>of</span> <span style=''>the</span> <span style=''>moving</span> <span style=''>window</span> <span style=''>methods</span> <span style=''>studied</span> <span style=''>On</span> <span style=''>the</span> <span style=''>majority</span> <span style=''>of</span> <span style=''>datasets</span> <span style=''>studied</span> <span style=''>the</span> <span style=''>RF</span> <span style=''>PLS</span> <span style='background-color:rgba( ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	automatic (0.0693496227093065)
# 	experimental (0.13618397412863817)
# 	representation (0.13151275601868487)
# 	segmentation (0.07402084081925979)
# 	architecture (0.0955803090190442)
# 	different (0.26410348544735895)
# 	information (0.2490118577075099)
# 	detection (0.1318720804886813)
# 	convolutional (0.14049586776859505)
# 	recognition (0.1433704635285663)
#
# Some Statistics words are:
# 	estimation (0.1576598909271195)
# 	theoretical (0.14774417451660882)
# 	optimization (0.18393653941497273)
# 	algorithm (0.37233515121467525)
# 	distribution (0.17699553792761527)
# 	stochastic (0.13485374318294496)
# 	statistical (0.16013882002974714)
# 	dimensional (0.17104610808130888)
# 	inference (0.1983143282102132)
# 	regression (0.17253346554288548)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="4be24dc4-a29d-4e74-9b77-2aaeb0364735" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4be24dc4-a29d-4e74-9b77-2aaeb0364735")) {                    Plotly.newPlot(                        "4be24dc4-a29d-4e74-9b77-2aaeb0364735",                        [{"x":["parameter","procedure","simulations","selection","regularization","parameters","functional","information","supervised","classification","effectiveness","algorithm","introduce","unlabeled","theoretic","viewpoints","estimated","discussed","discrimination","correctly","facilitate","dimensional","interpreted","motivates","projection","discriminative","intrinsic","formulation","connected","performed","extensive","structure","demonstrate","clustering","scientific","structures","embedding","equivalently","interpretation","representations","discovery","framework","integrate","visualization","naturally","generative","representation","experiments","reduction","traditional","dimensionality","downstream","probabilistic","topographic","evolutionary","constraints","geometric","specifications","prototype","manageable","optimizes","different","contributions","architectural","contribute","developing","significantly","requirements","estimates","performance","decisions","technique","practitioners","analyzing","evaluates","according","communication","potential","generates","sequential","algorithms","improvement","simulation","preferences","solutions","presented","adequately","iterative","important","optimization","alternative","synthesize","challenge","practical","converging","approaches","highlight","significant","approximation","understand","established","exploration","benchmark","extension","developed","successful","comparison","posterior","reinforcement","exploitation","attractive","applications","approximate","uncertainty","empirical","particular","contextual","neuroscientists","snapshots","introduces","fluctuation","decreasing","activities","multivariate","consonants","opportunity","techniques","overcoming","anatomical","challenges","therefore","smoothing","categories","effective","automatically","employing","experimental","visualizing","principled","establish","variables","construct","hierarchical","informative","computational","contribution","unsupervised","usefulness","complexity","maximally","synthetic","capturing","functions","distributed","factorization","tractable","properties","empirically","separability","scalability","favorable","implementation","demonstrates","separable","perspective","assumption","reformulate","deblurring","available","prototypical","denoising","measurability","compression","necessary","learnability","measurable","subspaces","hypotheses","condition","additionally","universally","compactness","guaranteed","distances","preserving","utilising","transformations","correlated","transforms","correlations","previously","investigate","similarity","transformation","resulting","forecasting","inference","optimizing","evaluation","autonomous","furthermore","propagate","prediction","recurrent","variational","distribution","incorporates","correlation","regression","shrinkage","estimator","redundancy","quadratic","conditions","dimension","diverging","collinearity","situations","competitors","adaptively","restricted","outperform","generalized","coefficient","consequently","strengths","estimation","components","eigenvalue","inequality","corresponding","estimating","proliferation","systematically","symmetric","competing","intuitive","transforming","capabilities","biological","existence","predicting","constructing","dramatically","application","addressed","relational","opportunities","increasingly","statistical","importance","retinopathy","segmented","detecting","generalization","specifi ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	neuroscientists
# 	consonants
# 	collinearity
# 	hyperbolic
# 	transformative
# 	cheminformatics
# 	correntropy
# 	thresholded
# 	embarrassingly
# 	reversing
# 	narrowing
# 	bivariate
# 	propensity
# 	degeneration
# 	omnipresent
# 	controllable
# 	affirmative
# 	precautions
# 	subsamples
# 	heckerman
# Some words which never appear in Statistics papers:
# 	deblurring
# 	retinopathy
# 	photographs
# 	hemorrhages
# 	microaneurysms
# 	maliciously
# 	populated
# 	inevitable
# 	strengthening
# 	deformation
# 	deforming
# 	stiffness
# 	articulated
# 	detections
# 	untrimmed
# 	satisfiability
# 	purchased
# 	costumers
# 	vehicular
# 	propositional

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.08442059159187e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7716666666666666
